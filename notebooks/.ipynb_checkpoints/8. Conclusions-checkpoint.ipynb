# %% [markdown]
# **Packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def srt_to_seconds(string):
    if type(string) != str:
        return string
    [hour, minute, second] = np.float_(string.split(':'))
    return second + minute*60 + hour*360

# %%
SimpleES = pd.read_csv('../data/results/SimpleES.csv')
Holt = pd.read_csv('../data/results/Holt.csv')
HoltWinters = pd.read_csv('../data/results/HoltWinters.csv')

# %%
SimpleES = SimpleES.set_index(HoltWinters.columns[0])
Holt = Holt.set_index(HoltWinters.columns[0])
HoltWinters = HoltWinters.set_index(HoltWinters.columns[0])

# %%
names = [SimpleES, Holt, HoltWinters]

mape = []
mse = []
time = []
for name in names:
    for metodo in name.columns:
        mape.append(name.loc['MAPE', metodo])
        mse.append(name.loc['MSE', metodo])
        time.append(name.loc['Time', metodo])

# %%
df = pd.DataFrame([mape, mse, time], columns=['SES1', 'SES2', 'SES3', 'Holt1', 'Holt2', 'Holt3', 'HW1', 'HW2', 'HW3', 'HW4'], index=['MAPE', 'MSE', 'Time'])
df = df.T

# %%
df.loc['SARIMA'] = [14.31, 17610999854.718975, '00:23:50.00']

# %%
df.loc['Prophet'] = [10.67, 17677685.275017653, '00:22:48']

# %%
df['Time'] = df['Time'].apply(srt_to_seconds)

# %%
df
# Out:
#                        MAPE                 MSE         Time
# SES1     102.09077948911114  2070655166.7148745     0.014078
# SES2      153.6646560764397  2095784007.4474676     0.010741
# SES3      99.83719826239066  2070649279.6376545     0.017595
# Holt1    23.161848062387744   139014615889.7526     0.187289
# Holt2     10.77698949140064   35697908645.16162     0.200706
# Holt3     7.031520246317564  15099016606.796297     0.161412
# HW1      24.130425263874898  101331982049.58644     0.976452
# HW2      17.089567083221226    41059889182.6787     1.551879
# HW3       21.92565177282149   77727479920.88379     0.962641
# HW4      15.750295387176664   30742572010.27659     1.379397
# SARIMA                14.31  17610999854.718975  1430.000000
# Prophet               10.67     17677685.275018  1368.000000

# %%
x = list(df.index.values)
y = list(np.float_(df['MAPE']))

plt.rcParams["figure.figsize"] = (10,4)
plt.bar(x, y, color=['red','red', 'red', 'yellow', 'yellow', 'yellow', 'green', 'green', 'green', 'green', 'blue', 'pink'])
plt.xlabel('Models')
plt.ylabel('')
plt.title('MAPE in the Exponential Smoothing Methods')
plt.show()

# %%
x = list(df.index.values)
y = list(np.float_(df['MAPE']))

plt.rcParams["figure.figsize"] = (10,4)
plt.bar(x, y, color=['red','red', 'red', 'yellow', 'yellow', 'yellow', 'green', 'green', 'green', 'green', 'blue', 'pink'])
plt.xlabel('Models')
plt.ylabel('')
plt.title('MAPE in the Exponential Smoothing Methods')
plt.show()

# %%
df.loc[['HW1', 'HW2', 'HW3', 'HW4', 'SARIMA']]
# Out:
#                       MAPE                 MSE         Time
# HW1     24.130425263874898  101331982049.58644     0.976452
# HW2     17.089567083221226    41059889182.6787     1.551879
# HW3      21.92565177282149   77727479920.88379     0.962641
# HW4     15.750295387176664   30742572010.27659     1.379397
# SARIMA               14.31  17610999854.718975  1430.000000

# %%
x = ['HW1', 'HW2', 'HW3', 'HW4', 'SARIMA', 'Prophet']
y = list(np.float_(df.loc[['HW1', 'HW2', 'HW3', 'HW4', 'SARIMA', 'Prophet']]['MAPE']))

plt.rcParams["figure.figsize"] = (10,4)
plt.bar(x, y, color=['green', 'green', 'green', 'green', 'blue', 'pink'])
plt.xlabel('Models')
plt.ylabel('')
plt.title('MAPE in the Exponential Smoothing Methods')
plt.show()

# %%
x = ['HW1', 'HW2', 'HW3', 'HW4', 'SARIMA', 'Prophet']
y = list(np.float_(df.loc[['HW1', 'HW2', 'HW3', 'HW4', 'SARIMA', 'Prophet']]['MSE']))

plt.rcParams["figure.figsize"] = (10,4)
plt.bar(x, y, color=['green', 'green', 'green', 'green', 'blue', 'pink'])
plt.xlabel('Models')
plt.ylabel('')
plt.title('MSE in the Exponential Smoothing Methods')
plt.show()

# %%
x = ['HW1', 'HW2', 'HW3', 'HW4', 'SARIMA', 'Prophet']
y = list(np.float_(df.loc[['HW1', 'HW2', 'HW3', 'HW4', 'SARIMA', 'Prophet']]['Time']))

plt.rcParams["figure.figsize"] = (10,4)
plt.bar(x, y, color=['green', 'green', 'green', 'green', 'blue', 'pink'])
plt.xlabel('Models')
plt.ylabel('')
plt.title('Time in the Exponential Smoothing Methods')
plt.show()

# %%
x = ['HW1', 'HW2', 'HW3', 'HW4']
y = list(np.float_(df.loc[['HW1', 'HW2', 'HW3', 'HW4']]['Time']))

plt.rcParams["figure.figsize"] = (10,4)
plt.bar(x, y, color=['green', 'green', 'green', 'green'])
plt.xlabel('Models')
plt.ylabel('Seconds (s)')
plt.title('Time in the Exponential Smoothing Methods')
plt.show()
